# %%
import numpy as np
import pandas as pd

# %%
from datetime import datetime

# %%
path_retail = "retail/retail_2016_2017.csv"
retail = pd.read_csv(path_retail)

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2024, 9, 28, 8, 4, 16, 117127)

# %%
type(now)
# Out:
# datetime.datetime

# %%
retail.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054944 entries, 0 to 1054943
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1054944 non-null  int64
#  1   date         1054944 non-null  object
#  2   store_nbr    1054944 non-null  int64
#  3   family       1054944 non-null  object
#  4   sales        1054944 non-null  float64
#  5   onpromotion  1054944 non-null  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 167.8 MB

# %%
retail = retail.astype({
    'date':'datetime64[ns]'
})

# %%
retail.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1054944 entries, 0 to 1054943
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1054944 non-null  int64
#  1   date         1054944 non-null  datetime64[ns]
#  2   store_nbr    1054944 non-null  int64
#  3   family       1054944 non-null  object
#  4   sales        1054944 non-null  float64
#  5   onpromotion  1054944 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 108.4 MB

# %%
now
# Out:
# datetime.datetime(2024, 9, 28, 8, 4, 16, 117127)

# %%
now.strftime('%B %d %Y')
# Out:
# 'September 28 2024'

# %%
retail
# Out:
#               id       date  store_nbr                      family     sales  \
# 0        1945944 2016-01-01          1                  AUTOMOTIVE     0.000
# 1        1945945 2016-01-01          1                   BABY CARE     0.000
# 2        1945946 2016-01-01          1                      BEAUTY     0.000
# 3        1945947 2016-01-01          1                   BEVERAGES     0.000
# 4        1945948 2016-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 1054939  3000883 2017-08-15          9                     POULTRY   438.133
# 1054940  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 1054941  3000885 2017-08-15          9                     PRODUCE  2419.729
# 1054942  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1054943  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 1054939            0
# 1054940            1
# 1054941          148
# 1054942            8
# 1054943            0
#
# [1054944 rows x 6 columns]

# %%
retail['date'].dt.strftime('%Y').head()
# Out:
# 0    2016
# 1    2016
# 2    2016
# 3    2016
# 4    2016
# Name: date, dtype: object

# %%
retail.assign(
    year = retail['date'].dt.year
)
# Out:
#               id       date  store_nbr                      family     sales  \
# 0        1945944 2016-01-01          1                  AUTOMOTIVE     0.000
# 1        1945945 2016-01-01          1                   BABY CARE     0.000
# 2        1945946 2016-01-01          1                      BEAUTY     0.000
# 3        1945947 2016-01-01          1                   BEVERAGES     0.000
# 4        1945948 2016-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 1054939  3000883 2017-08-15          9                     POULTRY   438.133
# 1054940  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 1054941  3000885 2017-08-15          9                     PRODUCE  2419.729
# 1054942  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1054943  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  year
# 0                  0  2016
# 1                  0  2016
# 2                  0  2016
# 3                  0  2016
# 4                  0  2016
# ...              ...   ...
# 1054939            0  2017
# 1054940            1  2017
# 1054941          148  2017
# 1054942            8  2017
# 1054943            0  2017
#
# [1054944 rows x 7 columns]

# %%
retail = retail.assign(
    birthday = pd.to_datetime('1950-01-01')
)

# %%
retail
# Out:
#               id       date  store_nbr                      family     sales  \
# 0        1945944 2016-01-01          1                  AUTOMOTIVE     0.000
# 1        1945945 2016-01-01          1                   BABY CARE     0.000
# 2        1945946 2016-01-01          1                      BEAUTY     0.000
# 3        1945947 2016-01-01          1                   BEVERAGES     0.000
# 4        1945948 2016-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 1054939  3000883 2017-08-15          9                     POULTRY   438.133
# 1054940  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 1054941  3000885 2017-08-15          9                     PRODUCE  2419.729
# 1054942  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1054943  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   birthday
# 0                  0 1950-01-01
# 1                  0 1950-01-01
# 2                  0 1950-01-01
# 3                  0 1950-01-01
# 4                  0 1950-01-01
# ...              ...        ...
# 1054939            0 1950-01-01
# 1054940            1 1950-01-01
# 1054941          148 1950-01-01
# 1054942            8 1950-01-01
# 1054943            0 1950-01-01
#
# [1054944 rows x 7 columns]

# %%
retail = retail.assign(
    age = (retail['date'] - retail['birthday']).dt.days / 365.25
)

retail
# Out:
#               id       date  store_nbr                      family     sales  \
# 0        1945944 2016-01-01          1                  AUTOMOTIVE     0.000
# 1        1945945 2016-01-01          1                   BABY CARE     0.000
# 2        1945946 2016-01-01          1                      BEAUTY     0.000
# 3        1945947 2016-01-01          1                   BEVERAGES     0.000
# 4        1945948 2016-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 1054939  3000883 2017-08-15          9                     POULTRY   438.133
# 1054940  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 1054941  3000885 2017-08-15          9                     PRODUCE  2419.729
# 1054942  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1054943  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   birthday        age
# 0                  0 1950-01-01  65.998631
# 1                  0 1950-01-01  65.998631
# 2                  0 1950-01-01  65.998631
# 3                  0 1950-01-01  65.998631
# 4                  0 1950-01-01  65.998631
# ...              ...        ...        ...
# 1054939            0 1950-01-01  67.619439
# 1054940            1 1950-01-01  67.619439
# 1054941          148 1950-01-01  67.619439
# 1054942            8 1950-01-01  67.619439
# 1054943            0 1950-01-01  67.619439
#
# [1054944 rows x 8 columns]

# %%
retail.assign(
    retirement_date = retail['date'] + (pd.to_timedelta(365.25,unit='D') * 20)
)
# Out:
#               id       date  store_nbr                      family     sales  \
# 0        1945944 2016-01-01          1                  AUTOMOTIVE     0.000
# 1        1945945 2016-01-01          1                   BABY CARE     0.000
# 2        1945946 2016-01-01          1                      BEAUTY     0.000
# 3        1945947 2016-01-01          1                   BEVERAGES     0.000
# 4        1945948 2016-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 1054939  3000883 2017-08-15          9                     POULTRY   438.133
# 1054940  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 1054941  3000885 2017-08-15          9                     PRODUCE  2419.729
# 1054942  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1054943  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   birthday        age retirement_date
# 0                  0 1950-01-01  65.998631      2036-01-01
# 1                  0 1950-01-01  65.998631      2036-01-01
# 2                  0 1950-01-01  65.998631      2036-01-01
# 3                  0 1950-01-01  65.998631      2036-01-01
# 4                  0 1950-01-01  65.998631      2036-01-01
# ...              ...        ...        ...             ...
# 1054939            0 1950-01-01  67.619439      2037-08-15
# 1054940            1 1950-01-01  67.619439      2037-08-15
# 1054941          148 1950-01-01  67.619439      2037-08-15
# 1054942            8 1950-01-01  67.619439      2037-08-15
# 1054943            0 1950-01-01  67.619439      2037-08-15
#
# [1054944 rows x 9 columns]

# %%
# retail.index = retail['date']

# %%
retail
# Out:
#               id       date  store_nbr                      family     sales  \
# 0        1945944 2016-01-01          1                  AUTOMOTIVE     0.000
# 1        1945945 2016-01-01          1                   BABY CARE     0.000
# 2        1945946 2016-01-01          1                      BEAUTY     0.000
# 3        1945947 2016-01-01          1                   BEVERAGES     0.000
# 4        1945948 2016-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 1054939  3000883 2017-08-15          9                     POULTRY   438.133
# 1054940  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 1054941  3000885 2017-08-15          9                     PRODUCE  2419.729
# 1054942  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1054943  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   birthday        age
# 0                  0 1950-01-01  65.998631
# 1                  0 1950-01-01  65.998631
# 2                  0 1950-01-01  65.998631
# 3                  0 1950-01-01  65.998631
# 4                  0 1950-01-01  65.998631
# ...              ...        ...        ...
# 1054939            0 1950-01-01  67.619439
# 1054940            1 1950-01-01  67.619439
# 1054941          148 1950-01-01  67.619439
# 1054942            8 1950-01-01  67.619439
# 1054943            0 1950-01-01  67.619439
#
# [1054944 rows x 8 columns]

# %%
retail.loc['2017-08']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 retail.loc['2017-08']
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: '2017-08'

# %%
retail_agg = retail.groupby(['date']).agg({
    'sales': 'sum'
}).round().iloc[1:10]

# %%
retail_agg
# Out:
#                 sales
# date
# 2016-01-02  1066677.0
# 2016-01-03  1226736.0
# 2016-01-04   955957.0
# 2016-01-05   835320.0
# 2016-01-06   821686.0
# 2016-01-07   653504.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.iloc[1] = np.NaN
retail_agg.iloc[4:6] = np.nan

# %%
retail_agg
# Out:
#                 sales
# date
# 2016-01-02  1066677.0
# 2016-01-03        NaN
# 2016-01-04   955957.0
# 2016-01-05   835320.0
# 2016-01-06        NaN
# 2016-01-07        NaN
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.fillna(retail_agg['sales'].mean())
# Out:
#                 sales
# date
# 2016-01-02  1066677.0
# 2016-01-03   942577.5
# 2016-01-04   955957.0
# 2016-01-05   835320.0
# 2016-01-06   942577.5
# 2016-01-07   942577.5
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.ffill()
# Out:
#                 sales
# date
# 2016-01-02  1066677.0
# 2016-01-03  1066677.0
# 2016-01-04   955957.0
# 2016-01-05   835320.0
# 2016-01-06   835320.0
# 2016-01-07   835320.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg = retail_agg.interpolate().round()

# %%
retail_agg
# Out:
#                 sales
# date
# 2016-01-02  1066677.0
# 2016-01-03  1011317.0
# 2016-01-04   955957.0
# 2016-01-05   835320.0
# 2016-01-06   794749.0
# 2016-01-07   754179.0
# 2016-01-08   713608.0
# 2016-01-09   989209.0
# 2016-01-10  1094694.0

# %%
retail_agg.assign(
    yesterday_sales = retail_agg['sales'].shift()
)
# Out:
#                 sales  yesterday_sales
# date
# 2016-01-02  1066677.0              NaN
# 2016-01-03  1011317.0        1066677.0
# 2016-01-04   955957.0        1011317.0
# 2016-01-05   835320.0         955957.0
# 2016-01-06   794749.0         835320.0
# 2016-01-07   754179.0         794749.0
# 2016-01-08   713608.0         754179.0
# 2016-01-09   989209.0         713608.0
# 2016-01-10  1094694.0         989209.0

# %%
retail_agg.assign(
    ratio = retail_agg['sales'] / retail_agg['sales'].shift()
)
# Out:
#                 sales     ratio
# date
# 2016-01-02  1066677.0       NaN
# 2016-01-03  1011317.0  0.948101
# 2016-01-04   955957.0  0.945259
# 2016-01-05   835320.0  0.873805
# 2016-01-06   794749.0  0.951431
# 2016-01-07   754179.0  0.948952
# 2016-01-08   713608.0  0.946205
# 2016-01-09   989209.0  1.386208
# 2016-01-10  1094694.0  1.106636

# %%
retail_agg.assign(
    diff = retail_agg['sales'] - retail_agg['sales'].shift()
)
# Out:
#                 sales      diff
# date
# 2016-01-02  1066677.0       NaN
# 2016-01-03  1011317.0  -55360.0
# 2016-01-04   955957.0  -55360.0
# 2016-01-05   835320.0 -120637.0
# 2016-01-06   794749.0  -40571.0
# 2016-01-07   754179.0  -40570.0
# 2016-01-08   713608.0  -40571.0
# 2016-01-09   989209.0  275601.0
# 2016-01-10  1094694.0  105485.0

# %%
retail_agg.assign(
    diff = retail_agg['sales'].diff()
)
# Out:
#                 sales      diff
# date
# 2016-01-02  1066677.0       NaN
# 2016-01-03  1011317.0  -55360.0
# 2016-01-04   955957.0  -55360.0
# 2016-01-05   835320.0 -120637.0
# 2016-01-06   794749.0  -40571.0
# 2016-01-07   754179.0  -40570.0
# 2016-01-08   713608.0  -40571.0
# 2016-01-09   989209.0  275601.0
# 2016-01-10  1094694.0  105485.0

# %%
retail.groupby([retail['date'].dt.year, retail['date'].dt.month]).agg({
    'sales': 'sum'
}).round(2)
# Out:
#                  sales
# date date
# 2016 1     23977804.89
#      2     21947408.80
#      3     23131780.88
#      4     25963025.10
#      5     24779432.26
#      6     22209218.58
#      7     23462672.43
#      8     22452414.32
#      9     22417448.10
#      10    24030389.82
#      11    24642640.20
#      12    29640287.58
# 2017 1     26328159.94
#      2     23250112.37
#      3     26704017.69
#      4     25895308.49
#      5     26911847.25
#      6     25682822.12
#      7     27011477.57
#      8     12433322.94

# %%
retail.set_index('date').loc[:,['sales']].resample('M').sum().round(2)
# Out:
#                   sales
# date
# 2016-01-31  23977804.89
# 2016-02-29  21947408.80
# 2016-03-31  23131780.88
# 2016-04-30  25963025.10
# 2016-05-31  24779432.26
# 2016-06-30  22209218.58
# 2016-07-31  23462672.43
# 2016-08-31  22452414.32
# 2016-09-30  22417448.10
# 2016-10-31  24030389.82
# 2016-11-30  24642640.20
# 2016-12-31  29640287.58
# 2017-01-31  26328159.94
# 2017-02-28  23250112.37
# 2017-03-31  26704017.69
# 2017-04-30  25895308.49
# 2017-05-31  26911847.25
# 2017-06-30  25682822.12
# 2017-07-31  27011477.57
# 2017-08-31  12433322.94

# %%
retail_daily = retail.set_index('date').loc[:,'sales'].resample('D').sum().round(2)

# %%
retail_daily
# Out:
# date
# 2016-01-01      16433.39
# 2016-01-02    1066677.42
# 2016-01-03    1226735.72
# 2016-01-04     955956.88
# 2016-01-05     835320.44
#                  ...
# 2017-08-11     826373.72
# 2017-08-12     792630.54
# 2017-08-13     865639.68
# 2017-08-14     760922.41
# 2017-08-15     762661.94
# Freq: D, Name: sales, Length: 593, dtype: float64

# %%
retail_daily.rolling(2).mean()
# Out:
# date
# 2016-01-01            NaN
# 2016-01-02     541555.405
# 2016-01-03    1146706.570
# 2016-01-04    1091346.300
# 2016-01-05     895638.660
#                  ...
# 2017-08-11     738880.315
# 2017-08-12     809502.130
# 2017-08-13     829135.110
# 2017-08-14     813281.045
# 2017-08-15     761792.175
# Freq: D, Name: sales, Length: 593, dtype: float64

# %%
retail_daily.rolling(2).mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
retail_daily.rolling(30).mean().plot()
# Out:
# <Axes: xlabel='date'>
